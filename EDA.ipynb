# %%
import pandas as pd

# %%
df = pd.read_csv('Cleaned_data.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# 0            3          0          4  ...              0          0
# 1            3          0          2  ...              0          0
# 2            3          0          4  ...              0          0
# 3            3          0          0  ...            272          0
# 4            3          0          2  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'Bsmt', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageCars', 'GarageArea', 'Garage',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df=df.drop(['Id'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   int64
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   int64
#  5   LotShape       1460 non-null   int64
#  6   LandContour    1460 non-null   int64
#  7   Utilities      1460 non-null   int64
#  8   LotConfig      1460 non-null   int64
#  9   LandSlope      1460 non-null   int64
#  10  Neighborhood   1460 non-null   int64
#  11  BldgType       1460 non-null   int64
#  12  HouseStyle     1460 non-null   int64
#  13  OverallQual    1460 non-null   int64
#  14  OverallCond    1460 non-null   int64
#  15  RoofStyle      1460 non-null   int64
#  16  RoofMatl       1460 non-null   int64
#  17  Exterior1st    1460 non-null   int64
# ...

# %%
#plot correlation matrix
import matplotlib.pyplot as plt
import seaborn as sns

corrmat = df.corr()

f, ax = plt.subplots(figsize=(20, 20))

sns.heatmap(corrmat, vmax=.8, square=True);

plt.show()

# %%
#show distribution of salesprice

sns.distplot(df['SalePrice'])

plt.show()
# Out:
# C:\Users\alisa\AppData\Local\Temp\ipykernel_2864\533123653.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SalePrice'])

# %%
#show scatterplot of SalePrice and OverallQual

var = 'OverallQual'
data = pd.concat([df['SalePrice'], df[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

plt.show()

# %%
#show scatterplot of SalePrice and GrLivArea

var = 'GrLivArea'
data = pd.concat([df['SalePrice'], df[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

plt.show()

# %%
# show boxplot of SalePrice and MSZoning

var = 'MSZoning'

data = pd.concat([df['SalePrice'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

plt.show()

# %%
# show boxplot of SalePrice and Neighborhood

var = 'Neighborhood'

data = pd.concat([df['SalePrice'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);

plt.show()

# %%
#show scatterplot of SalePrice and TotalBsmtSF

var = 'TotalBsmtSF'
data = pd.concat([df['SalePrice'], df[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

plt.show()

# %%
 #show scatterplot of SalePrice and 1stFlrSF and GrLivArea

var = '1stFlrSF'

data = pd.concat([df['SalePrice'], df[var]], axis=1)

data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

plt.show()

# %%
#show scatterplot of SalePrice and GarageArea

var = 'GarageArea'

data = pd.concat([df['SalePrice'], df[var]], axis=1)

data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

plt.show()

# %%
#pie chart of MSSubClass

df['MSSubClass'].value_counts().plot.pie(autopct='%1.1f%%')

plt.show()

# %%
#pie chart of MSZoning

df['MSZoning'].value_counts().plot.pie(autopct='%1.1f%%')

plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming corrmat and df are already defined

# Get the top 10 columns most correlated with 'SalePrice'
cols = corrmat.nlargest(10, 'SalePrice')['SalePrice'].index

# Compute the correlation matrix for these columns
cm = np.corrcoef(df[cols].values.T)

# Create a mask to select columns with a correlation coefficient less than a certain threshold
mask = np.abs(cm) < 0.5

# Get the indices of the columns that have less correlation with 'SalePrice'
less_correlated_indices = np.where(mask[0])[0]

# Get the column names of the less correlated columns
less_correlated_cols = cols[less_correlated_indices]

# Create a heatmap of the correlation matrix with the mask applied
plt.figure(figsize=(10, 8))
sns.heatmap(cm, mask=mask, cmap='coolwarm', annot=True, fmt='.2f', square=True, linewidths=0.5)

# Add labels and title
plt.title('Correlation Heatmap of Less Correlated Columns with respect to SalePrice')
plt.xlabel('Columns')
plt.ylabel('Columns')

# Add column names to the x-axis and y-axis tick labels
plt.xticks(range(len(cols)), cols, rotation=45, ha='right')
plt.yticks(range(len(cols)), cols, rotation=0)

# Show the plot
plt.show()

# %%
#plot distribution of overallqual and saleprice

var = 'OverallQual'

data = pd.concat([df['SalePrice'], df[var]], axis=1)

f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

plt.show()

# %%
#pie chart of totrmsabvgrd
plt.figure(figsize=(10, 10))
df['TotRmsAbvGrd'].value_counts().plot.pie(autopct='%1.1f%%')

plt.show()
